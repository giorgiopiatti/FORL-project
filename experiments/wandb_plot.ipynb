# %%
import wandb

api = wandb.Api()
runs = api.runs("eth-ticinesi/FORL_Briscola", filters={"tags": {"$in": ["ELO_POOL"]}})

# %%
t = runs[0].scan_history(keys=['test/ELO'])

for a in t:
    print(a)
# Out:
# {'test/ELO': 998.5700073242188}
# {'test/ELO': 999.8400268554688}
# {'test/ELO': 988.969970703125}
# {'test/ELO': 987.3350219726562}
# {'test/ELO': 994.5599975585938}
# {'test/ELO': 997.8099975585938}
# {'test/ELO': 1004.2349853515625}
# {'test/ELO': 992.9299926757812}
# {'test/ELO': 983.7999877929688}
# {'test/ELO': 992.5700073242188}
# {'test/ELO': 1003.010009765625}
# {'test/ELO': 985.3900146484375}
# {'test/ELO': 1006.39501953125}
# {'test/ELO': 999.8099975585938}
# {'test/ELO': 1000.2150268554688}
# {'test/ELO': 990.7050170898438}
# {'test/ELO': 1005.7050170898438}
# {'test/ELO': 994.2750244140625}
# {'test/ELO': 1004.1199951171875}
# {'test/ELO': 998.4099731445312}
# {'test/ELO': 996.6699829101562}
# {'test/ELO': 1011.0449829101562}
# {'test/ELO': 1016.2899780273438}
# {'test/ELO': 990.2449951171875}
# {'test/ELO': 994.655029296875}
# {'test/ELO': 1010.2000122070312}
# {'test/ELO': 999.6500244140625}
# {'test/ELO': 1014.9650268554688}
# {'test/ELO': 1010.22998046875}
# ...
